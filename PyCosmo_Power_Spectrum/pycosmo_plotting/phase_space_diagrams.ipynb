# %% [markdown]
# ### PHASE SPACE DIAGRAM GENERATION

# %% [markdown]
# #### INITIAL CONDITIONS WITH PY-COSMO GENERATED POWER SPECTRUM

# %%
# %pip install duckdb
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # X Y Z PHASE SPACE DIAGRAMS

# %%
fig, axs_x = plt.subplots(1, 2, figsize=(14, 6))

axs_x[0].hist(ngenic_results.iloc[:, 0], bins=100, color='blue')
axs_x[0].set_xlabel(r"$x \ [Mph/h]$", fontsize=14)
axs_x[0].set_ylabel(r"Frequency")
axs_x[0].set_title(r"N-GenIC x-coordinates")
axs_x[0].grid(True)

# Calculate the integral (area under the histogram) for N-GenIC x-coordinates
counts, bins, _ = axs_x[0].hist(ngenic_results.iloc[:, 0], bins=100)
bin_width = bins[1] - bins[0]
integral_ngenic_x = counts.sum() * bin_width

# Annotate the integral value on the histogram
axs_x[0].text(
    0.95, 0.95,
    f"Integral: {integral_ngenic_x:.2f}",
    transform=axs_x[0].transAxes,
    fontsize=12,
    verticalalignment='top',
    horizontalalignment='right',
    bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.7)
)

axs_x[1].hist(pycosmo_results.iloc[:, 0], bins=100)
axs_x[1].set_xlabel(r"$x \ [Mph/h]$", fontsize=14)
axs_x[1].set_ylabel(r"Frequency")
axs_x[1].set_title(r"PyCosmo x-coordinates")
axs_x[1].grid(True)

# Calculate the integral (area under the histogram) for Pycosmo x-coordinates
counts, bins, _ = axs_x[1].hist(pycosmo_results.iloc[:, 0], bins=100)
bin_width = bins[1] - bins[0]
integral_pycosmo_x = counts.sum() * bin_width

# Annotate the integral value on the histogram
axs_x[1].text(
    0.95, 0.95,
    f"Integral: {integral_pycosmo_x:.2f}",
    transform=axs_x[1].transAxes,
    fontsize=12,
    verticalalignment='top',
    horizontalalignment='right',
    bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.7)
)

plt.tight_layout()
plt.show()

# %%
fig, axs_y = plt.subplots(1, 2, figsize=(14, 6))

axs_y[0].hist(ngenic_results.iloc[:, 1], bins=100, color='blue')
axs_y[0].set_xlabel(r"$y \ [Mph/h]$", fontsize=14)
axs_y[0].set_ylabel(r"Frequency")
axs_y[0].set_title(r"N-GenIC y-coordinates")
axs_y[0].grid(True)


axs_y[1].hist(pycosmo_results.iloc[:, 1], bins=100)
axs_y[1].set_xlabel(r"$y \ [Mph/h]$", fontsize=14)
axs_y[1].set_ylabel(r"Frequency")
axs_y[1].set_title(r"PyCosmo y-coordinates")
axs_y[1].grid(True)

# Calculate the integral (area under the histogram)
counts, bins, _ = axs_y[0].hist(ngenic_results.iloc[:, 1], bins=100)
bin_width = bins[1] - bins[0]
integral_ngenic_y = counts.sum() * bin_width

# Annotate the integral value on the histogram
axs_y[0].text(
    0.95, 0.95,
    f"Integral: {integral_ngenic_y:.2f}",
    transform=axs_y[0].transAxes,
    fontsize=12,
    verticalalignment='top',
    horizontalalignment='right',
    bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.7)
)


# Calculate the integral (area under the histogram) for N-GenIC x-coordinates
counts, bins, _ = axs_y[1].hist(pycosmo_results.iloc[:, 1], bins=100)
bin_width = bins[1] - bins[0]
integral_pycosmo_y = counts.sum() * bin_width

# Annotate the integral value on the histogram
axs_y[1].text(
    0.95, 0.95,
    f"Integral: {integral_pycosmo_y:.2f}",
    transform=axs_y[1].transAxes,
    fontsize=12,
    verticalalignment='top',
    horizontalalignment='right',
    bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.7)
)

plt.tight_layout()
plt.show()

# %%
fig, axs_z = plt.subplots(1, 2, figsize=(14, 6))

axs_z[0].hist(ngenic_results.iloc[:, 2], bins=100, color='blue')
axs_z[0].set_xlabel(r"$z \ [Mph/h]$", fontsize=14)
axs_z[0].set_ylabel(r"Frequency")
axs_z[0].set_title(r"N-GenIC z-coordinates")
axs_z[0].grid(True)

# Calculate the integral (area under the histogram) for N-GenIC x-coordinates
counts, bins, _ = axs_z[0].hist(ngenic_results.iloc[:, 2], bins=100)
bin_width = bins[1] - bins[0]
integral_ngenic_z = counts.sum() * bin_width

# Annotate the integral value on the histogram
axs_z[0].text(
    0.95, 0.95,
    f"Integral: {integral_ngenic_z:.2f}",
    transform=axs_z[0].transAxes,
    fontsize=12,
    verticalalignment='top',
    horizontalalignment='right',
    bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.7)
)

axs_z[1].hist(pycosmo_results.iloc[:, 2], bins=100)
axs_z[1].set_xlabel(r"$z \ [Mph/h]$", fontsize=14)
axs_z[1].set_ylabel(r"Frequency")
axs_z[1].set_title(r"PyCosmo z-coordinates")
axs_z[1].grid(True)

# Calculate the integral (area under the histogram) for Pycosmo x-coordinates
counts, bins, _ = axs_z[1].hist(pycosmo_results.iloc[:, 2], bins=100)
bin_width = bins[1] - bins[0]
integral_pycosmo_z = counts.sum() * bin_width

# Annotate the integral value on the histogram
axs_z[1].text(
    0.95, 0.95,
    f"Integral: {integral_pycosmo_z:.2f}",
    transform=axs_z[1].transAxes,
    fontsize=12,
    verticalalignment='top',
    horizontalalignment='right',
    bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.7)
)

plt.tight_layout()
plt.show()

# %%
'''____________________ VX VY VZ PHASE SPACE DIAGRAMS ____________________'''

fig, axs = plt.subplots(1, 2, figsize=(14, 6))

axs[0].hist(ngenic_results.iloc[:, 3], bins=100, color='blue')
axs[0].set_xlabel(r"$v_x \ [cm/s]$")
axs[0].set_ylabel(r"Frequency")
axs[0].set_title(r"N-GenIC x-velocities")
axs[0].grid(True)

# Calculate the integral (area under the histogram) for N-GenIC x-coordinates
counts, bins, _ = axs[0].hist(ngenic_results.iloc[:, 3], bins=100)
bin_width = bins[1] - bins[0]
integral_ngenic_vx = counts.sum() * bin_width

# Annotate the integral value on the histogram
axs[0].text(
    0.95, 0.95,
    f"Integral: {integral_ngenic_vx:.2f}",
    transform=axs[0].transAxes,
    fontsize=12,
    verticalalignment='top',
    horizontalalignment='right',
    bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.7)
)

axs[1].hist(pycosmo_results.iloc[:, 3], bins=100)
axs[1].set_xlabel(r"$v_x \ [cm/s]$")
axs[1].set_ylabel(r"Frequency")
axs[1].set_title(r"PyCosmo x-velocities)")
axs[1].grid(True)

# Calculate the integral (area under the histogram) for Pycosmo x-coordinates
counts, bins, _ = axs[1].hist(pycosmo_results.iloc[:, 3], bins=100)
bin_width = bins[1] - bins[0]
integral_pycosmo_vx = counts.sum() * bin_width

# Annotate the integral value on the histogram
axs[1].text(
    0.95, 0.95,
    f"Integral: {integral_pycosmo_vx:.2f}",
    transform=axs[1].transAxes,
    fontsize=12,
    verticalalignment='top',
    horizontalalignment='right',
    bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.7)
)

plt.tight_layout()
plt.show()

# %%
fig, axs_vy = plt.subplots(1, 2, figsize=(14, 6))

axs_vy[0].hist(ngenic_results.iloc[:, 4], bins=100, color='blue')
axs_vy[0].set_xlabel(r"$v_y$ [cm/s]")
axs_vy[0].set_ylabel("Frequency")
axs_vy[0].set_title(r"N-GenIC y-velocities")
axs_vy[0].grid(True)

# Calculate the integral (area under the histogram) for N-GenIC x-coordinates
counts, bins, _ = axs_vy[0].hist(ngenic_results.iloc[:, 4], bins=100)
bin_width = bins[1] - bins[0]
integral_ngenic_vy = counts.sum() * bin_width

# Annotate the integral value on the histogram
axs_vy[0].text(
    0.95, 0.95,
    f"Integral: {integral_ngenic_vy:.2f}",
    transform=axs_vy[0].transAxes,
    fontsize=12,
    verticalalignment='top',
    horizontalalignment='right',
    bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.7)
)

axs_vy[1].hist(pycosmo_results.iloc[:, 4], bins=100)
axs_vy[1].set_xlabel(r"$v_y$ [cm/s]")
axs_vy[1].set_ylabel("Frequency")
axs_vy[1].set_title(r"PyCosmo y-velocities")
axs_vy[1].grid(True)

# Calculate the integral (area under the histogram) for Pycosmo x-coordinates
counts, bins, _ = axs_vy[1].hist(pycosmo_results.iloc[:, 4], bins=100)
bin_width = bins[1] - bins[0]
integral_pycosmo_vy = counts.sum() * bin_width

# Annotate the integral value on the histogram
axs_vy[1].text(
    0.95, 0.95,
    f"Integral: {integral_pycosmo_vy:.2f}",
    transform=axs_vy[1].transAxes,
    fontsize=12,
    verticalalignment='top',
    horizontalalignment='right',
    bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.7)
)

plt.tight_layout()
plt.show()

# %%
fig, axs_vz = plt.subplots(1, 2, figsize=(14, 6))

axs_vz[0].hist(ngenic_results.iloc[:, 5], bins=100, color='blue')
axs_vz[0].set_xlabel(r"$v_z \ [cm/s]$")
axs_vz[0].set_ylabel(r"Frequency")
axs_vz[0].set_title(r"N-GenIC z-velocities")
axs_vz[0].grid(True)

# Calculate the integral (area under the histogram) for N-GenIC x-coordinates
counts, bins, _ = axs_vz[0].hist(ngenic_results.iloc[:, 5], bins=100)
bin_width = bins[1] - bins[0]
integral_ngenic_vz = counts.sum() * bin_width

# Annotate the integral value on the histogram
axs_vz[0].text(
    0.95, 0.95,
    f"Integral: {integral_ngenic_vx:.2f}",
    transform=axs_vz[0].transAxes,
    fontsize=12,
    verticalalignment='top',
    horizontalalignment='right',
    bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.7)
)

axs_vz[1].hist(pycosmo_results.iloc[:, 5], bins=100)
axs_vz[1].set_xlabel(r"$v_z \ [cm/s]$")
axs_vz[1].set_ylabel(r"Frequency")
axs_vz[1].set_title(r"PyCosmo z-velocities")
axs_vz[1].grid(True)

# Calculate the integral (area under the histogram) for Pycosmo x-coordinates
counts, bins, _ = axs_vz[1].hist(pycosmo_results.iloc[:, 5], bins=100)
bin_width = bins[1] - bins[0]
integral_pycosmo_vz = counts.sum() * bin_width

# Annotate the integral value on the histogram
axs_vz[1].text(
    0.95, 0.95,
    f"Integral: {integral_pycosmo_vz:.2f}",
    transform=axs_vz[1].transAxes,
    fontsize=12,
    verticalalignment='top',
    horizontalalignment='right',
    bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.7)
)

plt.tight_layout()
plt.show()

# %%
# Calculate the integral (area under the histogram) for N-GenIC x-coordinates
counts, bins, _ = axs_x[0].hist(ngenic_results.iloc[:, 0], bins=100)
bin_width = bins[1] - bins[0]
integral_ngenic_x = counts.sum() * bin_width

# Annotate the integral value on the histogram
axs_x[0].text(
    0.95, 0.95,
    f"Integral: {integral_ngenic_x:.2f}",
    transform=axs_x[0].transAxes,
    fontsize=12,
    verticalalignment='top',
    horizontalalignment='right',
    bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.7)
)

axs_x[1].hist(pycosmo_results.iloc[:, 0], bins=100)
axs_x[1].set_xlabel(r"$x \ [Mph/h]$", fontsize=14)
axs_x[1].set_ylabel(r"Frequency")
axs_x[1].set_title(r"PyCosmo x-coordinates")
axs_x[1].grid(True)

# Calculate the integral (area under the histogram) for N-GenIC x-coordinates
counts, bins, _ = axs_x[1].hist(pycosmo_results.iloc[:, 0], bins=100)
bin_width = bins[1] - bins[0]
integral_pycosmo_x = counts.sum() * bin_width

# Annotate the integral value on the histogram
axs_x[1].text(
    0.95, 0.95,
    f"Integral: {integral_pycosmo_x:.2f}",
    transform=axs_x[1].transAxes,
    fontsize=12,
    verticalalignment='top',
    horizontalalignment='right',
    bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.7)
)

plt.tight_layout()
plt.show()

fig, axs_y = plt.subplots(1, 2, figsize=(14, 6))

axs_y[0].hist(ngenic_results.iloc[:, 1], bins=100)
axs_y[0].set_xlabel(r"$y \ [Mph/h]$", fontsize=14)
axs_y[0].set_ylabel(r"Frequency")
axs_y[0].set_title(r"N-GenIC y-coordinates")
axs_y[0].grid(True)

axs_y[1].hist(pycosmo_results.iloc[:, 1], bins=100)
axs_y[1].set_xlabel(r"$y \ [Mph/h]$", fontsize=14)
axs_y[1].set_ylabel(r"Frequency")
axs_y[1].set_title(r"PyCosmo y-coordinates")
axs_y[1].grid(True)

plt.tight_layout()
plt.show()

fig, axs_z = plt.subplots(1, 2, figsize=(14, 6))

axs_z[0].hist(ngenic_results.iloc[:, 2], bins=100)
axs_z[0].set_xlabel(r"$z \ [Mph/h]$", fontsize=14)
axs_z[0].set_ylabel(r"Frequency")
axs_z[0].set_title(r"N-GenIC z-coordinates")
axs_z[0].grid(True)

axs_z[1].hist(pycosmo_results.iloc[:, 2], bins=100)
axs_z[1].set_xlabel(r"$z \ [Mph/h]$", fontsize=14)
axs_z[1].set_ylabel(r"Frequency")
axs_z[1].set_title(r"PyCosmo z-coordinates")
axs_z[1].grid(True)

plt.tight_layout()
plt.show()

'''____________________ VX VY VZ PHASE SPACE DIAGRAMS ____________________'''

fig, axs = plt.subplots(1, 2, figsize=(14, 6))

axs[0].hist(ngenic_results.iloc[:, 3], bins=100)
axs[0].set_xlabel(r"$v_x$ \ [cm/s]")
axs[0].set_ylabel(r"Frequency")
axs[0].set_title(r"N-GenIC z-velocities")
axs[0].grid(True)

axs[1].hist(pycosmo_results.iloc[:, 3], bins=100)
axs[1].set_xlabel(r"$v_x$ \ [cm/s]")
axs[1].set_ylabel(r"Frequency")
axs[1].set_title(r"PyCosmo x-velocities)")
axs[1].grid(True)

plt.tight_layout()
plt.show()

fig, axs_vy = plt.subplots(1, 2, figsize=(14, 6))

axs_vy[0].hist(ngenic_results.iloc[:, 4], bins=100)
axs_vy[0].set_xlabel(r"$v_y$ [cm/s]")
axs_vy[0].set_ylabel("Frequency")
axs_vy[0].set_title(r"N-GenIC y-velocities")
axs_vy[0].grid(True)

axs_vy[1].hist(pycosmo_results.iloc[:, 4], bins=100)
axs_vy[1].set_xlabel(r"$v_y$ [cm/s]")
axs_vy[1].set_ylabel("Frequency")
axs_vy[1].set_title(r"PyCosmo y-velocities")
axs_vy[1].grid(True)

plt.tight_layout()
plt.show()

fig, axs_vz = plt.subplots(1, 2, figsize=(14, 6))

axs_vz[0].hist(ngenic_results.iloc[:, 5], bins=100)
axs_vz[0].set_xlabel(r"$v_z$ [cm/s]")
axs_vz[0].set_ylabel(r"Frequency")
axs_vz[0].set_title(r"N-GenIC z-velocities")
axs_vz[0].grid(True)

axs_vz[1].hist(pycosmo_results.iloc[:, 5], bins=100)
axs_vz[0].set_xlabel(r"$v_y$ [cm/s]")
axs_vz[1].set_ylabel(r"Frequency")
axs_vz[1].set_title(r"PyCosmo z-velocities")
axs_vz[1].grid(True)

plt.tight_layout()
plt.show()

# %%
'''____________________ POSITION-VELOCITY PHASE SPACE DIAGRAMS ____________________'''

# Plot ngenic x-vx and pycosmo x-vx phase space density side by side
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

h1 = axs[0].hist2d(ngenic_results.iloc[:, 0], ngenic_results.iloc[:, 3], bins=100, cmap='viridis')
axs[0].set_xlabel("x")
axs[0].set_ylabel("vx")
axs[0].set_title("ngenic x-vx Phase Space Density")
axs[0].grid(True)
plt.colorbar(h1[3], ax=axs[0], label="Counts")

h2 = axs[1].hist2d(pycosmo_results.iloc[:, 0], pycosmo_results.iloc[:, 3], bins=100, cmap='viridis')
axs[1].set_xlabel("x")
axs[1].set_ylabel("vx")
axs[1].set_title("Pycosmo x-vx Phase Space Density")
axs[1].grid(True)
plt.colorbar(h2[3], ax=axs[1], label="Counts")

plt.tight_layout()
plt.show()

# Plot ngenic y-vy and pycosmo y-vy phase space density side by side
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

h1 = axs[0].hist2d(ngenic_results.iloc[:, 1], ngenic_results.iloc[:, 4], bins=100, cmap='viridis')
axs[0].set_xlabel("y")
axs[0].set_ylabel("vy")
axs[0].set_title("ngenic x-vx Phase Space Density")
axs[0].grid(True)
plt.colorbar(h1[3], ax=axs[0], label="Counts")

h2 = axs[1].hist2d(pycosmo_results.iloc[:, 1], pycosmo_results.iloc[:, 4], bins=100, cmap='viridis')
axs[1].set_xlabel("y")
axs[1].set_ylabel("vy")
axs[1].set_title("Pycosmo x-vx Phase Space Density")
axs[1].grid(True)
plt.colorbar(h2[3], ax=axs[1], label="Counts")

plt.tight_layout()
plt.show()

# Plot ngenic z-vz and pycosmo z-vz phase space density side by side
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

h1 = axs[0].hist2d(ngenic_results.iloc[:, 2], ngenic_results.iloc[:, 5], bins=100, cmap='viridis')
axs[0].set_xlabel("z")
axs[0].set_ylabel("vz")
axs[0].set_title("ngenic y-vy Phase Space Density")
axs[0].grid(True)
plt.colorbar(h1[3], ax=axs[0], label="Counts")

h2 = axs[1].hist2d(pycosmo_results.iloc[:, 2], pycosmo_results.iloc[:, 5], bins=100, cmap='viridis')
axs[1].set_xlabel("z")
axs[1].set_ylabel("vz")
axs[1].set_title("pycosmo y-vy Phase Space Density")
axs[1].grid(True)
plt.colorbar(h2[3], ax=axs[1], label="Counts")

plt.tight_layout()
plt.show()
